# %% [markdown]
# INTRODUCTION TO OPEN CV AND IMAGE PROCESSING

# %%
#pip install opencv-python, install it in terminal
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'/Users/asleshakamera/Desktop/DSANDML/elephant.jpg')
img
# Out:
# array([[[223, 207, 195],
#         [219, 203, 191],
#         [214, 198, 186],
#         ...,
#         [207, 196, 182],
#         [206, 195, 181],
#         [206, 195, 181]],
#
#        [[221, 205, 193],
#         [217, 201, 189],
#         [213, 197, 185],
#         ...,
#         [206, 195, 181],
#         [206, 195, 181],
#         [205, 194, 180]],
#
#        [[219, 203, 191],
#         [216, 200, 188],
#         [211, 195, 183],
#         ...,
#         [205, 194, 180],
#         [205, 194, 180],
#         [204, 193, 179]],
#
#        ...,
#
#        [[ 62,  99, 149],
#         [ 52,  92, 141],
#         [ 64, 106, 159],
#         ...,
#         [ 73, 125, 166],
#         [ 68, 118, 160],
#         [ 59, 111, 151]],
#
#        [[ 75, 115, 164],
#         [ 82, 123, 172],
#         [ 68, 110, 163],
#         ...,
#         [ 89, 141, 187],
#         [ 87, 137, 183],
#         [ 86, 139, 182]],
#
#        [[ 57,  98, 147],
#         [ 87, 130, 179],
#         [ 65, 107, 160],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(img) #Blue Green and Red for OpenCv
plt.show()

# %%
img
# Out:
# array([[[223, 207, 195],
#         [219, 203, 191],
#         [214, 198, 186],
#         ...,
#         [207, 196, 182],
#         [206, 195, 181],
#         [206, 195, 181]],
#
#        [[221, 205, 193],
#         [217, 201, 189],
#         [213, 197, 185],
#         ...,
#         [206, 195, 181],
#         [206, 195, 181],
#         [205, 194, 180]],
#
#        [[219, 203, 191],
#         [216, 200, 188],
#         [211, 195, 183],
#         ...,
#         [205, 194, 180],
#         [205, 194, 180],
#         [204, 193, 179]],
#
#        ...,
#
#        [[ 62,  99, 149],
#         [ 52,  92, 141],
#         [ 64, 106, 159],
#         ...,
#         [ 73, 125, 166],
#         [ 68, 118, 160],
#         [ 59, 111, 151]],
#
#        [[ 75, 115, 164],
#         [ 82, 123, 172],
#         [ 68, 110, 163],
#         ...,
#         [ 89, 141, 187],
#         [ 87, 137, 183],
#         [ 86, 139, 182]],
#
#        [[ 57,  98, 147],
#         [ 87, 130, 179],
#         [ 65, 107, 160],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Changing from BGR to RGB
fix_img
# Out:
# array([[[195, 207, 223],
#         [191, 203, 219],
#         [186, 198, 214],
#         ...,
#         [182, 196, 207],
#         [181, 195, 206],
#         [181, 195, 206]],
#
#        [[193, 205, 221],
#         [189, 201, 217],
#         [185, 197, 213],
#         ...,
#         [181, 195, 206],
#         [181, 195, 206],
#         [180, 194, 205]],
#
#        [[191, 203, 219],
#         [188, 200, 216],
#         [183, 195, 211],
#         ...,
#         [180, 194, 205],
#         [180, 194, 205],
#         [179, 193, 204]],
#
#        ...,
#
#        [[149,  99,  62],
#         [141,  92,  52],
#         [159, 106,  64],
#         ...,
#         [166, 125,  73],
#         [160, 118,  68],
#         [151, 111,  59]],
#
#        [[164, 115,  75],
#         [172, 123,  82],
#         [163, 110,  68],
#         ...,
#         [187, 141,  89],
#         [183, 137,  87],
#         [182, 139,  86]],
#
#        [[147,  98,  57],
#         [179, 130,  87],
#         [160, 107,  65],
# ...

# %%
fix_img.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(fix_img) 
plt.show()

# %%
img_gray = cv2.imread(r'/Users/asleshakamera/Desktop/DSANDML/elephant.jpg',cv2.IMREAD_GRAYSCALE)
img_gray.shape
img_gray
# Out:
# array([[205, 201, 196, ..., 193, 192, 192],
#        [203, 199, 195, ..., 192, 192, 191],
#        [201, 198, 193, ..., 191, 191, 190],
#        ...,
#        [110, 102, 117, ..., 131, 125, 117],
#        [125, 133, 121, ..., 149, 145, 146],
#        [108, 140, 118, ..., 114, 121, 137]], dtype=uint8)

# %%
plt.imshow(img_gray) 
plt.show()

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 251

# %%
plt.imshow(img_gray,cmap='grey') 
plt.show()

# %%
plt.imshow(img_gray,cmap='Accent') 
plt.show()

# %%
plt.imshow(fix_img) 
plt.show()

# %%
fix_img.shape
# Out:
# (408, 612, 3)

# %%
fix_img1 = cv2.resize(fix_img,(204,306)) #Resizing the image by half

# %%
fix_img1.shape
# Out:
# (306, 204, 3)

# %%
w_ratio = 0.5 #Width ratio
h_ratio = 0.5 #Height Ratio 
fix_img2 = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img2
# Out:
# array([[[192, 204, 220],
#         [184, 196, 212],
#         [181, 194, 210],
#         ...,
#         [183, 199, 212],
#         [182, 196, 207],
#         [181, 195, 206]],
#
#        [[190, 202, 218],
#         [182, 194, 210],
#         [178, 191, 207],
#         ...,
#         [181, 197, 210],
#         [180, 194, 205],
#         [179, 193, 204]],
#
#        [[189, 201, 217],
#         [185, 197, 213],
#         [182, 195, 211],
#         ...,
#         [177, 193, 206],
#         [175, 191, 204],
#         [174, 190, 203]],
#
#        ...,
#
#        [[150, 100,  65],
#         [175, 120,  82],
#         [152,  94,  50],
#         ...,
#         [142,  98,  49],
#         [137, 104,  54],
#         [145, 116,  65]],
#
#        [[141,  91,  54],
#         [170, 117,  75],
#         [169, 112,  65],
#         ...,
#         [169, 122,  73],
#         [172, 130,  80],
#         [157, 119,  68]],
#
#        [[166, 117,  75],
#         [170, 117,  73],
#         [191, 134,  84],
# ...

# %%
fix_img2.shape
# Out:
# (204, 306, 3)

# %%
plt.imshow(fix_img2) 
plt.show()

# %%
img3= cv2.flip(fix_img2,0)
plt.imshow(img3) 
plt.show()

# %%
img3= cv2.flip(fix_img2,1)
plt.imshow(img3) 
plt.show()

# %%
cv2.imwrite('new genai image.jpg',img3)
# Out:
# True

# %% [markdown]
# PRACTICAL 2 Done
